# %%
# !tensorboard --logdir runs --host 0.0.0.0 --port 6006
# Out:
# /Users/vladislavkalinichenko/VSCodeProjects/Probabilistic-JEPA/venv/lib/python3.13/site-packages/tensorboard/default.py:30: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# TensorFlow installation not found - running with reduced feature set.
# TensorBoard 2.20.0 at http://0.0.0.0:6006/ (Press CTRL+C to quit)
# ^C
